# %%
import numpy as np
import matplotlib.pyplot as plt
import os
np.sort( os.listdir() )
# Out:
# array(['.ipynb_checkpoints', 'Untitled.ipynb', 'g102_0822.dat',
#        'g102_0824.dat', 'g102_0828.dat', 'g141_0822.dat', 'g141_0826.dat',
#        'g141_0828.dat'], dtype='<U18')

# %%
wl, flux, ferr = np.loadtxt( 'g102_0822.dat', skiprows=3 ).T
plt.plot(wl, flux)
wl, flux, ferr = np.loadtxt( 'g141_0822.dat', skiprows=3 ).T
plt.plot(wl, flux)

# %%
plt.figure(figsize=(10,7) )

wl, flux, ferr = np.loadtxt( 'g102_0822.dat', skiprows=3 ).T
plt.errorbar(wl, flux, yerr = ferr, color='C0', ds='steps')
wl, flux, ferr = np.loadtxt( 'g141_0822.dat', skiprows=3 ).T
plt.errorbar(wl, flux, yerr = ferr, color='C0', ds='steps')

wl, flux, ferr = np.loadtxt( 'g102_0824.dat', skiprows=3 ).T
plt.errorbar(wl, flux, yerr = ferr, color='C1', ds='steps')
#wl, flux, ferr = np.loadtxt( 'g141_0824.dat', skiprows=3 ).T
#plt.plot(wl, flux, color='C3')

#wl, flux, ferr = np.loadtxt( 'g102_0826.dat', skiprows=3 ).T
#plt.plot(wl, flux, color='C3')
wl, flux, ferr = np.loadtxt( 'g141_0826.dat', skiprows=3 ).T
plt.errorbar(wl, flux, yerr = ferr, color='C2', ds='steps')


wl, flux, ferr = np.loadtxt( 'g102_0828.dat', skiprows=3 ).T
plt.errorbar(wl, flux, yerr = ferr, color='C3', ds='steps')
wl, flux, ferr = np.loadtxt( 'g141_0828.dat', skiprows=3 ).T
plt.errorbar(wl, flux, yerr = ferr, color='C3', ds='steps')

plt.yscale('log')
plt.xlim(7900, 17000)
# Out:
# (7900.0, 17000.0)

# %%
print( (6.5e9)**3 * 1e66 / (13.7e9) )
# Out:
# 2.0045620437956204e+85

# %%
print( (66e9)**3 * 1e66 )
# Out:
# 2.87496e+98

# %%
print( (6.5e9)**3 * 1e66  )
# Out:
# 2.74625e+95
