# %%
#!/usr/local/anaconda3/envs/py36 python
# -*- coding: utf-8 -*-

# Imports
import numpy as np
from scipy.signal import medfilt
import lmfit
#from util import *
import corner
import pickle

def main():


    OBs = ["OB1", "OB1_conv", "OB1_with_assym", "OB2", "OB2_conv", "OB2_with_assym", "OB3", "OB3_n", "OB3_n2", "OB4", "OB4_n", "OB4_n2", "OB5", "OB5_n2"]#, 'OB1', "OB2", "OB3", "OB4"]

    for ii, OB in enumerate(OBs):
        p = lmfit.Parameters()

        if OB == "OB1":
            p.add_many(('T',        5417   , True, 2500 , 7500),
                       ('N',        1.3e-29, True),
                       ('vphot',    0.27   , True, 0    , 1),
                       ('vmax',     0.338  , True, 0, 1),
                       ('t0',       126000 , False),
                       ('tau',      2.3      , True, 0, 100),
                       ('vref',     0.     , False, 0, 1),
                       ('ve',       0.23   , True, 0, 1),
                       ('occult',   0.01   , True, 0, 2),
                       ('amp1',     0.26   , True, 0, 1),
                       ('amp2',     0.42   , True, 0, 1),
                       ('cen1',     15500e-10,  False, 14000e-10, 17000e-10),
                       ('cen2',     20200e-10,  False, 19000e-10, 22000e-10),
                       ('sig1',     580e-10,  False, 100e-10, 3000e-10),
                       ('sig2',     800e-10,  False, 100e-10, 3000e-10)
                       )
        if OB == "OB1_with_assym":
            p.add_many(('T',        5436   , True, 2500 , 7500),
                       ('N',        1.34e-29, True),
                       ('vphot',    0.28   , True, 0    , 1),
                       ('vmax',     0.338  , True, 0, 1),
                       ('t0',       126000 , False),
                       ('tau',      1.69   , True, 0, 100),
                       ('vref',     0.     , False, 0, 1),
                       ('ve',       0.31   , True, 0, 1),
                       ('occult',   0.03   , True, 0, 2),
                       ('amp1',     0.28   , True, 0, 1),
                       ('amp2',     0.44   , True, 0, 1),
                       ('cen1',     15500e-10,  False, 14000e-10, 17000e-10),
                       ('cen2',     20200e-10,  False, 19000e-10, 22000e-10),
                       ('sig1',     580e-10,  False, 100e-10, 3000e-10),
                       ('sig2',     800e-10,  False, 100e-10, 3000e-10), 
                       ('ratio_vel',0.99      , True, 0.8, 1.2 )
                       )    
            
        if OB == "OB1_conv":
            p.add_many(('T',        5417   , True, 2500 , 7500),
                       ('N',        1.3e-29, True),
                       ('vphot',    0.27   , True, 0    , 1),
                       ('vmax',     0.338  , True, 0, 1),
                       ('t0',       126000 , False),
                       ('tau',      2.3      , True, 0, 100),
                       ('vref',     0.     , False, 0, 1),
                       ('ve',       0.23   , True, 0, 1),
                       ('v_bb',     0.27   , True, 0, 1),
                       ('T_power',  0.40   , True, 0, 1),
                       ('occult',   0.01   , True, 0, 2),
                       ('amp1',     0.26   , True, 0, 1),
                       ('amp2',     0.42   , True, 0, 1),
                       ('cen1',     15500e-10,  False, 14000e-10, 17000e-10),
                       ('cen2',     20200e-10,  False, 19000e-10, 22000e-10),
                       ('sig1',     580e-10,  False, 100e-10, 3000e-10),
                       ('sig2',     800e-10,  False, 100e-10, 3000e-10)
                       )        
        if OB == "OB2":
            p.add_many(('T',        3950  , True, 2500 , 7500),
                       ('N',        2.7e-29 , True),
                       ('vphot',    0.24  , True, 0    , 1),
                       ('vmax',     0.3312 , True, 0, 1),
                       ('t0',       212400, False),
                       ('tau',      10.0   , True, 0, 20),
                       ('vref',     0.     , False, 0, 1),
                       ('ve',       0.11   , True, 0, 0.2),
                       ('occult',   1.84   , True, 0.1, 10),
                       ('amp1',     0.62 , True, 0.01, 5),
                       ('amp2',     0.24 , True, 0.01, 5),
                       ('cen1',     15500e-10,  False, 14000e-10, 17000e-10),
                       ('cen2',     20200e-10,  False, 19000e-10, 22000e-10),
                       ('sig1',     580e-10,  False, 100e-10, 3000e-10),
                       ('sig2',     742e-10,  False, 100e-10, 3000e-10)
                       )
        if OB == "OB2_with_assym":
            p.add_many(('T',        3920  , True, 2500 , 7500),
                       ('N',        2.7e-29 , True),
                       ('vphot',    0.248  , True, 0    , 1),
                       ('vmax',     0.279 , True, 0, 1),
                       ('t0',       212400, False),
                       ('tau',      1.9   , True, 0, 20),
                       ('vref',     0.     , False, 0, 1),
                       ('ve',       0.67   , True, 0, 0.2),
                       ('occult',   1.26   , True, 0.1, 10),
                       ('amp1',     0.52 , True, 0.01, 5),
                       ('amp2',     0.53 , True, 0.01, 5),
                       ('cen1',     15500e-10,  False, 14000e-10, 17000e-10),
                       ('cen2',     20200e-10,  False, 19000e-10, 22000e-10),
                       ('sig1',     1083e-10 ,  False, 100e-10, 3000e-10),
                       ('sig2',     742e-10  ,  False, 100e-10, 3000e-10),
                       ('ratio_vel',1      , True, 0.8, 1.2 )
                       )
            
        
        if OB == "OB2_conv":
            p.add_many(('T',        3950  , True, 2500 , 7500),
                       ('N',        2.7e-29 , True),
                       ('vphot',    0.24  , True, 0    , 1),
                       ('vmax',     0.3312 , True, 0, 1),
                       ('t0',       212400, False),
                       ('tau',      10.0   , True, 0, 20),
                       ('vref',     0.     , False, 0, 1),
                       ('ve',       0.11   , True, 0, 0.2),
                       ('v_bb',     0.24   , True, 0, 1),
                       ('T_power',  0.40   , True, 0, 3),
                       ('occult',   1.84   , True, 0.1, 10),
                       ('amp1',     0.62 , True, 0.01, 5),
                       ('amp2',     0.24 , True, 0.01, 5),
                       ('cen1',     15500e-10,  False, 14000e-10, 17000e-10),
                       ('cen2',     20200e-10,  False, 19000e-10, 22000e-10),
                       ('sig1',     580e-10,  False, 100e-10, 3000e-10),
                       ('sig2',     742e-10,  False, 100e-10, 3000e-10)
                       )
            
        if OB == "OB3":
            p.add_many(('T',        3400  , True, 2500 , 7500),
                       ('N',        2e-29 , True),
                       ('vphot',    0.23  , True, 0    , 1),
                       ('vmax',     0.28  , True, 0, 1),
                       ('t0',       298800, False),
                       ('tau',      2     , True, 0, 10),
                       ('vref',     0.    , False, 0, 1),
                       ('ve',       0.9  , True, 0, 1),
                       ('occult',   3.    , True, 0.1, 10),
                       ('amp1',     0.88,  False, 0.01, 5),
                       ('amp2',     0.71,  False, 0.01, 5),
                       ('cen1',     15500e-10,  False, 14000e-10, 17000e-10),
                       ('cen2',     20200e-10,  False, 19000e-10, 22000e-10),
                       ('sig1',     550e-10,  False, 100e-10, 3000e-10),
                       ('sig2',     1110e-10, False, 100e-10, 3000e-10)
                       )
        
        if OB == "OB3_n":
            p.add_many(('T',        3390  , True, 2500 , 7500),
                       ('N',        3.94e-29 , True),
                       ('vphot',    0.204  , True, 0    , 1),
                       ('vmax',     0.232  , True, 0, 1),
                       ('t0',       298800, False),
                       ('tau',      1.77     , True, 0, 10),
                       ('vref',     0.    , False, 0, 1),
                       ('ve',       5.4  , True, 0, 100),
                       ('occult',   3.4    , True, 0.1, 10),
                       ('amp1',     0.95,  False, 0.01, 5),
                       ('amp2',     0.78,  False, 0.01, 5),
                       ('amp3',     0.15,  True, -1, 1),
                       ('cen1',     15500e-10,  False, 14000e-10, 17000e-10),
                       ('cen2',     20200e-10,  False, 19000e-10, 22000e-10),
                       ('cen3',     7500e-10,  False, 1000e-10, 10000e-10),
                       ('sig1',     580e-10,  False, 100e-10, 3000e-10),
                       ('sig2',     1460e-10, False, 100e-10, 3000e-10),
                       ('sig3',     600e-10, True, 100e-10, 3000e-10)
                       )
        if OB == "OB3_n2":
            p.add_many(('T',        3390  , True, 2500 , 7500),
                       ('N',        3.94e-29 , True),
                       ('vphot',    0.204  , True, 0    , 1),
                       ('vmax',     0.232  , True, 0, 1),
                       ('t0',       298800, False),
                       ('tau',      1.77     , True, 0, 10),
                       ('vref',     0.    , False, 0, 1),
                       ('ve',       5.4  , True, 0, 100),
                       ('occult',   3.4    , True, 0.1, 10),
                       ('amp1',     0.95,  False, 0.01, 5),
                       ('amp2',     0.78,  False, 0.01, 5),
                       ('amp3',     -0.03,  True, -1, 1),
                       ('cen1',     15250e-10,  False, 14000e-10, 17000e-10),
                       ('cen2',     20200e-10,  False, 19000e-10, 22000e-10),
                       ('cen3',     6500e-10 ,  False, 1000e-10, 10000e-10),
                       ('sig1',     580e-10,  False, 100e-10, 3000e-10),
                       ('sig2',     1460e-10, False, 100e-10, 3000e-10),
                       ('sig3',     400e-10, True, 100e-10, 3000e-10)
                       )
        if OB == "OB4":
            p.add_many(('T',        3200       , True, 2500 , 7500),
                       ('N',        3.034e-29  , True),
                       ('vphot',    0.13       , True, 0, 1),
                       ('vmax',     0.2349     , True, 0, 1),
                       ('t0',       385200     , False),
                       ('tau',      1.2        , True, 0, 10),
                       ('vref',     0.0        , False, 0, 1),
                       ('ve',       0.074      , True, 0, 1), #0.074
                       ('occult',   12         , True, 0.1, 20),
                       ('amp1',     0.81       , True, 0.01, 5),
                       ('amp2',     0.757      , True, 0.01, 5),
                       ('cen1',     15500e-10  , False, 14000e-10, 17000e-10),
                       ('cen2',     20200e-10  , False, 19000e-10, 22000e-10),
                       ('sig1',     550e-10    , False, 100e-10, 3000e-10),
                       ('sig2',     1110e-10   , False, 100e-10, 3000e-10)
                       )
            
        if OB == "OB4_n":
            p.add_many(('T',        3240       , True, 2500 , 7500),
                       ('N',        3.034e-29  , True),
                       ('vphot',    0.184    , True, 0, 1),
                       ('vmax',     0.232     , True, 0, 1),
                       ('t0',       385200     , False),
                       ('tau',      0.49        , True, 0, 10),
                       ('vref',     0.0        , False, 0, 1),
                       ('ve',       1.403      , True, 0, 10), #0.074
                       ('occult',   7.666      , True, 0.1, 20),
                       ('amp1',     0.88       , True, 0.01, 5),
                       ('amp2',     0.80       , True, 0.01, 5),
                       ('amp3',     0.05        , True, -1, 1),
                       ('cen1',     15500e-10  , False, 14000e-10, 17000e-10),
                       ('cen2',     20200e-10  , False, 19000e-10, 22000e-10),
                       ('cen3',     7500e-10   , False, 1000e-10, 10000e-10),
                       ('sig1',     700e-10    , False, 100e-10, 3000e-10),
                       ('sig2',     1510e-10   , False, 100e-10, 3000e-10),
                       ('sig3',     250e-10    , True, 100e-10, 3000e-10)
                       )
        if OB == "OB4_n2":
            p.add_many(('T',        3240       , True, 2500 , 7500),
                       ('N',        3.034e-29  , True),
                       ('vphot',    0.184    , True, 0, 1),
                       ('vmax',     0.232     , True, 0, 1),
                       ('t0',       385200     , False),
                       ('tau',      0.49        , True, 0, 10),
                       ('vref',     0.0        , False, 0, 1),
                       ('ve',       1.403      , True, 0, 10), #0.074
                       ('occult',   7.666      , True, 0.1, 20),
                       ('amp1',     0.88       , True, 0.01, 5),
                       ('amp2',     0.80       , True, 0.01, 5),
                       ('amp3',     -0.05        , True, -1, 1),
                       ('cen1',     15500e-10  , False, 14000e-10, 17000e-10),
                       ('cen2',     20200e-10  , False, 19000e-10, 22000e-10),
                       ('cen3',     6500e-10   , False, 1000e-10, 10000e-10),
                       ('sig1',     700e-10    , False, 100e-10, 3000e-10),
                       ('sig2',     1510e-10   , False, 100e-10, 3000e-10),
                       ('sig3',     300e-10    , True, 100e-10, 3000e-10)
                       )
        if OB == "OB5":
            p.add_many(('T',        2800       , True, 2500 , 7500),
                       ('N',        3.034e-29  , True),
                       ('vphot',    0.135       , True, 0, 1),
                       ('vmax',     0.2349     , True, 0, 1),
                       ('t0',       471600     , False),
                       ('tau',      0.4        , True, 0, 10),
                       ('vref',     0.0        , False, 0, 1),
                       ('ve',       0.2        , True, 0, 1), #0.074
                       ('occult',   12         , True, 0.1, 20),
                       ('amp1',     0.81       , True, 0.01, 5),
                       ('amp2',     0.757      , True, 0.01, 5),
                       ('cen1',     15500e-10  , False, 14000e-10, 17000e-10),
                       ('cen2',     20200e-10  , False, 19000e-10, 22000e-10),
                       ('sig1',     550e-10    , False, 100e-10, 3000e-10),
                       ('sig2',     1110e-10   , False, 100e-10, 3000e-10)
                       )
        if OB == "OB5_n2":
            p.add_many(('T',        3082       , True, 2500 , 7500),
                       ('N',        3.55e-29   , True),
                       ('vphot',    0.146      , True, 0, 1),
                       ('vmax',     0.219      , True, 0, 1),
                       ('t0',       471600     , False),
                       ('tau',      0.18       , True, 0, 10),
                       ('vref',     0.0        , False, 0, 1),
                       ('ve',       0.31       , True, 0, 10), #0.074
                       ('occult',   20         , True, 0.1, 40),
                       ('amp1',     1.05       , True, 0.01, 5),
                       ('amp2',     1.23       , True, 0.01, 5),
                       ('amp3',     -0.2       , True, -1, 1),
                       ('cen1',     15500e-10  , False, 14000e-10, 17000e-10),
                       ('cen2',     20200e-10  , False, 19000e-10, 22000e-10),
                       ('cen3',     6500e-10   , False, 1000e-10, 22000e-10),
                       ('sig1',     720e-10    , False, 100e-10, 3000e-10),
                       ('sig2',     1610e-10   , False, 100e-10, 3000e-10),
                       ('sig3',     300e-10   , False, 100e-10, 3000e-10)
                       )
        #with open("./data/%s_w_gaussians.json"%OB, 'w') as outfile:
        #    p.dump(outfile)
        #with open("./data/%s_init_no_gaussian_low_v_2.json"%OB, 'w') as outfile:
        #    p.dump(outfile)
            
        with open("./data/%s_init.json"%OB, 'w') as outfile:
            print("./data/%s_init.json"%OB)
            p.dump(outfile)

if __name__ == '__main__':
    main()
# Out:
# ./data/OB1_init.json
# ./data/OB1_conv_init.json
# ./data/OB1_with_assym_init.json
# ./data/OB2_init.json
# ./data/OB2_conv_init.json
# ./data/OB2_with_assym_init.json
# ./data/OB3_init.json
# ./data/OB3_n_init.json
# ./data/OB3_n2_init.json
# ./data/OB4_init.json
# ./data/OB4_n_init.json
# ./data/OB4_n2_init.json
# ./data/OB5_init.json
# ./data/OB5_n2_init.json

# %%
#!/usr/local/anaconda3/envs/py36 python
# -*- coding: utf-8 -*-

# Imports
import numpy as np
from scipy.signal import medfilt
import lmfit
#from util import *
import corner
import pickle

def main():


    OBs = ["OB2_760Pcygni", "OB3_760Pcygni", "OB4_760Pcygni", "OB5_760Pcygni"]

    for ii, OB in enumerate(OBs):
        p = lmfit.Parameters()

        if OB == "OB2_760Pcygni":
            p.add_many(('T',        3935       , True, 2500 , 7500),
                       ('N',        2.75e-29    , True),
                       ('vphot',    0.247      , True, 0, 1),
                       ('vmax',     0.279      , True, 0, 1),
                       ('t0',       212400     , False),
                       ('tau',      1.7        , True, 0, 10),
                       ('vref',     0.0        , False, 0, 1),
                       ('ve',       0.78        , True, 0, 20), #0.074
                       ('occult',   1.47       , True, 0.1, 20),
                       ('amp1',     0.73       , True, 0.01, 5),
                       ('amp2',     0.77       , True, 0.01, 5),
                       ('cen1',     15100e-10  , False, 14000e-10, 17000e-10),
                       ('cen2',     19000e-10  , False, 19000e-10, 22000e-10),
                       ('sig1',     664e-10    , False, 100e-10, 3000e-10),
                       ('sig2',     1260e-10   , False, 100e-10, 3000e-10), 
                       ('v_out_n' ,   0.28     , True, 0, 1), 
                       ('v_phot_n',   0.247    , True, 0, 1), 
                       ('tau_n'   ,   0.1      , True, 0, 10), 
                       ('lambda_n',   7500     , True, 6500, 9000), 
                       ('ve_n'    ,   0.5      , True, 0, 10) 
                       )
            
        if OB == "OB3_760Pcygni":
            p.add_many(('T',        3394       , True, 2500 , 7500),
                       ('N',        3.8e-29    , True),
                       ('vphot',    0.204      , True, 0, 1),
                       ('vmax',     0.233      , True, 0, 1),
                       ('t0',       298800     , False),
                       ('tau',      1.6        , True, 0, 10),
                       ('vref',     0.0        , False, 0, 1),
                       ('ve',       6.6        , True, 0, 20), #0.074
                       ('occult',   3.5       , True, 0.1, 20),
                       ('amp1',     0.96       , True, 0.01, 5),
                       ('amp2',     0.80       , True, 0.01, 5),
                       ('cen1',     15500e-10  , False, 14000e-10, 17000e-10),
                       ('cen2',     20200e-10  , False, 19000e-10, 22000e-10),
                       ('sig1',     664e-10    , False, 100e-10, 3000e-10),
                       ('sig2',     1440e-10   , False, 100e-10, 3000e-10), 
                       ('v_out_n' ,     0.24   , True, 0, 1), 
                       ('v_phot_n',     0.20   , True, 0, 1), 
                       ('tau_n'   ,     .4     , True, 0, 10), 
                       ('lambda_n',     7500   , True, 7000, 9000), 
                       ('ve_n'    ,     1      , True, 0, 10) 
                       )
        
        if OB == "OB4_760Pcygni":
            p.add_many(('T',        3220       , True, 2500 , 7500),
                       ('N',        3.2e-29    , True),
                       ('vphot',    0.173      , True, 0, 1),
                       ('vmax',     0.23       , True, 0, 1),
                       ('t0',       385200     , False),
                       ('tau',      0.383      , True, 0, 10),
                       ('vref',     0.0        , False, 0, 1),
                       ('ve',       7.1        , True, 0, 20), #0.074
                       ('occult',   7.65       , True, 0.1, 20),
                       ('amp1',     0.92       , True, 0.01, 5),
                       ('amp2',     0.90       , True, 0.01, 5),
                       ('cen1',     15500e-10  , False, 14000e-10, 17000e-10),
                       ('cen2',     20200e-10  , False, 19000e-10, 22000e-10),
                       ('sig1',     664e-10    , False, 100e-10, 3000e-10),
                       ('sig2',     1440e-10   , False, 100e-10, 3000e-10), 
                       ('v_out_n' ,     0.21   , True, 0, 1), 
                       ('v_phot_n',     0.17   , True, 0, 1), 
                       ('tau_n'   ,     .3     , True, 0, 10), 
                       ('lambda_n',     7700   , True, 7000, 9000), 
                       ('ve_n'    ,     1      , True, 0, 10) 
                       )
        if OB == "OB5_760Pcygni":
            p.add_many(('T',        3080       , True, 2500 , 7500),
                       ('N',        3.5e-29    , True),
                       ('vphot',    0.146      , True, 0, 1),
                       ('vmax',     0.22       , True, 0, 1),
                       ('t0',       466560     , False),
                       ('tau',      0.18      , True, 0, 10),
                       ('vref',     0.0        , False, 0, 1),
                       ('ve',       0.31        , True, 0, 20), #0.074
                       ('occult',   19       , True, 0.1, 20),
                       ('amp1',     1.05       , True, 0.01, 5),
                       ('amp2',     1.23       , True, 0.01, 5),
                       ('cen1',     15500e-10  , False, 14000e-10, 17000e-10),
                       ('cen2',     20200e-10  , False, 19000e-10, 22000e-10),
                       ('sig1',     726e-10    , False, 100e-10, 3000e-10),
                       ('sig2',     1620e-10   , False, 100e-10, 3000e-10), 
                       ('v_out_n' ,     0.21   , True, 0, 1), 
                       ('v_phot_n',     0.146   , True, 0, 1), 
                       ('tau_n'   ,     .3     , True, 0, 10), 
                       ('lambda_n',     7600   , True, 7000, 9000), 
                       ('ve_n'    ,     1      , True, 0, 10) 
                       )
            
            
        with open("./data/%s_init.json"%OB, 'w') as outfile:
            print("./data/%s_init.json"%OB)
            p.dump(outfile)
            
if __name__ == '__main__':
    main()
# Out:
# ./data/OB2_760Pcygni_init.json
# ./data/OB3_760Pcygni_init.json
# ./data/OB4_760Pcygni_init.json
# ./data/OB5_760Pcygni_init.json

# %%
5.4*3600*24
# Out:
# 466560.0

# %%
5.458*3600*24
# Out:
# 471571.19999999995

# %%
#!/usr/local/anaconda3/envs/py36 python
# -*- coding: utf-8 -*-

# Imports
import numpy as np
from scipy.signal import medfilt
import lmfit
#from util import *
import corner
import pickle

def main():


    OBs = ["OB1_with_assym_incl", "OB2_with_assym", "OB3_with_assym_incl", "OB4_with_assym_incl", "OB5_with_assym_incl"]#, 'OB1', "OB2", "OB3", "OB4"]

    for ii, OB in enumerate(OBs):
        p = lmfit.Parameters()
        if OB == "OB1_with_assym_incl":
            p.add_many(('T',        5436   , True, 2500 , 7500),
                       ('N',        1.34e-29, True),
                       ('vphot',    0.28   , True, 0    , 1),
                       ('vmax',     0.338  , True, 0, 1),
                       ('t0',       126000 , False),
                       ('tau',      1.69   , True, 0, 100),
                       ('vref',     0.     , False, 0, 1),
                       ('ve',       0.31   , True, 0, 1),
                       ('occult',   0.03   , True, 0, 2),
                       ('amp1',     0.28   , True, 0, 1),
                       ('amp2',     0.44   , True, 0, 1),
                       ('cen1',     15500e-10,  False, 14000e-10, 17000e-10),
                       ('cen2',     20200e-10,  False, 19000e-10, 22000e-10),
                       ('sig1',     580e-10,  False, 100e-10, 3000e-10),
                       ('sig2',     800e-10,  False, 100e-10, 3000e-10), 
                       ('ratio_vel',1.02      , True, 0.8, 1.2 )
                       )    
            

        if OB == "OB2_with_assym":
            p.add_many(('T',        3920  , True, 2500 , 7500),
                       ('N',        2.7e-29 , True),
                       ('vphot',    0.248  , True, 0    , 1),
                       ('vmax',     0.279 , True, 0, 1),
                       ('t0',       212400, False),
                       ('tau',      1.9   , True, 0, 20),
                       ('vref',     0.     , False, 0, 1),
                       ('ve',       0.67   , True, 0, 0.2),
                       ('occult',   1.26   , True, 0.1, 10),
                       ('amp1',     0.52 , True, 0.01, 5),
                       ('amp2',     0.53 , True, 0.01, 5),
                       ('cen1',     15500e-10,  False, 14000e-10, 17000e-10),
                       ('cen2',     20200e-10,  False, 19000e-10, 22000e-10),
                       ('sig1',     1083e-10 ,  False, 100e-10, 3000e-10),
                       ('sig2',     742e-10  ,  False, 100e-10, 3000e-10),
                       ('ratio_vel',0.999      , True, 0.8, 1.2 )
                       )
            
        if OB == "OB3_with_assym_incl":
            p.add_many(('T',        3394     , True, 2500 , 7500),
                       ('N',        3.8e-29  , True),
                       ('vphot',    0.204    , True, 0    , 1),
                       ('vmax',     0.233    , True, 0, 1),
                       ('t0',       298800   , False),
                       ('tau',      1.67     , True, 0, 20),
                       ('vref',     0.       , False, 0, 1),
                       ('ve',       6.62     , True, 0, 20),
                       ('occult',   3.52     , True, 0.1, 10),
                       ('amp1',     0.96     , True, 0.01, 5),
                       ('amp2',     0.80     , True, 0.01, 5),
                       ('cen1',     15500e-10, False, 14000e-10, 17000e-10),
                       ('cen2',     20200e-10, False, 19000e-10, 22000e-10),
                       ('sig1',     591e-10  , False, 100e-10, 3000e-10),
                       ('sig2',     1479e-10 , False, 100e-10, 3000e-10),
                       ('ratio_vel',0.9        , True, 0.8, 1.2 )
                       )
            
        if OB == "OB4_with_assym_incl":
            p.add_many(('T',        3200       , True, 2500 , 7500),
                       ('N',        3.2e-29  , True),
                       ('vphot',    0.173      , True, 0, 1),
                       ('vmax',     0.227      , True, 0, 1),
                       ('t0',       385200     , False),
                       ('tau',      0.38        , True, 0, 10),
                       ('vref',     0.0        , False, 0, 1),
                       ('ve',       7.1        , True, 0, 20), #0.074
                       ('occult',   7.6        , True, 0.1, 20),
                       ('amp1',     0.81       , True, 0.01, 5),
                       ('amp2',     0.757      , True, 0.01, 5),
                       ('cen1',     15500e-10  , False, 14000e-10, 17000e-10),
                       ('cen2',     20200e-10  , False, 19000e-10, 22000e-10),
                       ('sig1',     550e-10    , False, 100e-10, 3000e-10),
                       ('sig2',     1110e-10   , False, 100e-10, 3000e-10),
                       ('ratio_vel',0.99        , True, 0.8, 1.2 )
                       )
            
        if OB == "OB5_with_assym_incl":
            p.add_many(('T',        3057       , True, 2500 , 7500),
                       ('N',        3.7e-29    , True),
                       ('vphot',    0.148      , True, 0, 1),
                       ('vmax',     0.222      , True, 0, 1),
                       ('t0',       471600     , False),
                       ('tau',      0.2        , True, 0, 10),
                       ('vref',     0.0        , False, 0, 1),
                       ('ve',       0.3        , True, 0, 1), #0.074
                       ('occult',   20         , True, 0.1,  100),
                       ('amp1',     1.11       , True, 0.01, 5),
                       ('amp2',     1.26       , True, 0.01, 5),
                       ('cen1',     15500e-10  , False, 14000e-10, 17000e-10),
                       ('cen2',     20200e-10  , False, 19000e-10, 22000e-10),
                       ('sig1',     550e-10    , False, 100e-10, 3000e-10),
                       ('sig2',     1110e-10   , False, 100e-10, 3000e-10), 
                       ('ratio_vel',0.99        , True, 0.8, 1.2 )
                       )

        #with open("./data/%s_w_gaussians.json"%OB, 'w') as outfile:
        #    p.dump(outfile)
        #with open("./data/%s_init_no_gaussian_low_v_2.json"%OB, 'w') as outfile:
        #    p.dump(outfile)
            
        with open("./data/%s_init.json"%OB, 'w') as outfile:
            print("./data/%s_init.json"%OB)
            p.dump(outfile)

if __name__ == '__main__':
    main()
# Out:
# ./data/OB1_with_assym_incl_init.json
# ./data/OB2_with_assym_init.json
# ./data/OB3_with_assym_incl_init.json
# ./data/OB4_with_assym_incl_init.json
# ./data/OB5_with_assym_incl_init.json

# %%
#!/usr/local/anaconda3/envs/py36 python
# -*- coding: utf-8 -*-

# Imports
import numpy as np
from scipy.signal import medfilt
import lmfit
#from util import *
import corner
import pickle

def main():


    OBs = ["OB1_with_fixed_assym_freeinc", "OB2_with_fixed_assym_freeinc"]#, 'OB1', "OB2", "OB3", "OB4"]

    for ii, OB in enumerate(OBs):
        p = lmfit.Parameters()
        if OB == "OB1_with_fixed_assym_freeinc":
            p.add_many(('T',        5436   , True, 2500 , 7500),
                       ('N',        1.34e-29, True),
                       ('vphot',    0.28   , True, 0    , 1),
                       ('vmax',     0.338  , True, 0, 1),
                       ('t0',       126000 , False),
                       ('tau',      1.69   , True, 0, 100),
                       ('vref',     0.     , False, 0, 1),
                       ('ve',       0.31   , True, 0, 1),
                       ('occult',   0.03   , True, 0, 2),
                       ('amp1',     0.28   , True, 0, 1),
                       ('amp2',     0.44   , True, 0, 1),
                       ('cen1',     15500e-10,  False, 14000e-10, 17000e-10),
                       ('cen2',     20200e-10,  False, 19000e-10, 22000e-10),
                       ('sig1',     580e-10,  False, 100e-10, 3000e-10),
                       ('sig2',     800e-10,  False, 100e-10, 3000e-10), 
                       ('ratio_vel',1.02      , True, 0.8, 1.2 ),
                       ('inclin'   ,21       , True, 0  , 90)
                       )    
            

        if OB == "OB2_with_assym_with_inc":
            p.add_many(('T',        3920  , True, 2500 , 7500),
                       ('N',        2.76e-29 , True),
                       ('vphot',    0.248  , True, 0    , 1),
                       ('vmax',     0.279 , True, 0, 1),
                       ('t0',       212400, False),
                       ('tau',      7.33   , True, 0, 20),
                       ('vref',     0.     , False, 0, 1),
                       ('ve',       0.15   , True, 0, 2),
                       ('occult',   1.26   , True, 0.1, 10),
                       ('amp1',     0.57 , True, 0.01, 5),
                       ('amp2',     0.57 , True, 0.01, 5),
                       ('cen1',     15500e-10,  False, 14000e-10, 17000e-10),
                       ('cen2',     20200e-10,  False, 19000e-10, 22000e-10),
                       ('sig1',     1083e-10 ,  False, 100e-10, 3000e-10),
                       ('sig2',     742e-10  ,  False, 100e-10, 3000e-10),
                       ('ratio_vel',0.998    , False, 0.8, 1.2 ), 
                       ('inclin'   ,21       , True, 0  , 90)
                       )
            
        if OB == "OB3_with_assym_with_inc":
            p.add_many(('T',        3394     , True, 2500 , 7500),
                       ('N',        3.8e-29  , True),
                       ('vphot',    0.204    , True, 0    , 1),
                       ('vmax',     0.233    , True, 0, 1),
                       ('t0',       298800   , False),
                       ('tau',      1.67     , True, 0, 20),
                       ('vref',     0.       , False, 0, 1),
                       ('ve',       6.62     , True, 0, 20),
                       ('occult',   3.52     , True, 0.1, 10),
                       ('amp1',     0.96     , True, 0.01, 5),
                       ('amp2',     0.80     , True, 0.01, 5),
                       ('cen1',     15500e-10, False, 14000e-10, 17000e-10),
                       ('cen2',     20200e-10, False, 19000e-10, 22000e-10),
                       ('sig1',     591e-10  , False, 100e-10, 3000e-10),
                       ('sig2',     1479e-10 , False, 100e-10, 3000e-10),
                       ('ratio_vel',1        , True, 0.8, 1.2 )
                       )
            
        if OB == "OB4_with_assym_with_inc":
            p.add_many(('T',        3200       , True, 2500 , 7500),
                       ('N',        3.2e-29  , True),
                       ('vphot',    0.173      , True, 0, 1),
                       ('vmax',     0.227      , True, 0, 1),
                       ('t0',       385200     , False),
                       ('tau',      0.38        , True, 0, 10),
                       ('vref',     0.0        , False, 0, 1),
                       ('ve',       7.1        , True, 0, 20), #0.074
                       ('occult',   7.6        , True, 0.1, 20),
                       ('amp1',     0.81       , True, 0.01, 5),
                       ('amp2',     0.757      , True, 0.01, 5),
                       ('cen1',     15500e-10  , False, 14000e-10, 17000e-10),
                       ('cen2',     20200e-10  , False, 19000e-10, 22000e-10),
                       ('sig1',     550e-10    , False, 100e-10, 3000e-10),
                       ('sig2',     1110e-10   , False, 100e-10, 3000e-10),
                       ('ratio_vel',1        , True, 0.8, 1.2 )
                       )
            
        if OB == "OB5_with_assym_with_inc":
            p.add_many(('T',        3057       , True, 2500 , 7500),
                       ('N',        3.7e-29    , True),
                       ('vphot',    0.148      , True, 0, 1),
                       ('vmax',     0.222      , True, 0, 1),
                       ('t0',       471600     , False),
                       ('tau',      0.2        , True, 0, 10),
                       ('vref',     0.0        , False, 0, 1),
                       ('ve',       0.3        , True, 0, 1), #0.074
                       ('occult',   20         , True, 0.1,  100),
                       ('amp1',     1.11       , True, 0.01, 5),
                       ('amp2',     1.26       , True, 0.01, 5),
                       ('cen1',     15500e-10  , False, 14000e-10, 17000e-10),
                       ('cen2',     20200e-10  , False, 19000e-10, 22000e-10),
                       ('sig1',     550e-10    , False, 100e-10, 3000e-10),
                       ('sig2',     1110e-10   , False, 100e-10, 3000e-10), 
                       ('ratio_vel',1        , True, 0.8, 1.2 )
                       )

        #with open("./data/%s_w_gaussians.json"%OB, 'w') as outfile:
        #    p.dump(outfile)
        #with open("./data/%s_init_no_gaussian_low_v_2.json"%OB, 'w') as outfile:
        #    p.dump(outfile)
            
        with open("./data/%s_init.json"%OB, 'w') as outfile:
            print("./data/%s_init.json"%OB)
            p.dump(outfile)

if __name__ == '__main__':
    main()
# Out:
# ./data/OB1_with_fixed_assym_freeinc_init.json
# ./data/OB2_with_fixed_assym_freeinc_init.json

# %%
#!/usr/local/anaconda3/envs/py36 python
# -*- coding: utf-8 -*-

# Imports
import numpy as np
from scipy.signal import medfilt
import lmfit
#from util import *
import corner
import pickle

def main():


    OBs = ["OB1_one_line", "OB2_one_line"]#, 'OB1', "OB2", "OB3", "OB4"]

    for ii, OB in enumerate(OBs):
        p = lmfit.Parameters()
        if OB == "OB1_one_line":
            p.add_many(('T',        5436   , True, 2500 , 7500),
                       ('N',        1.34e-29, True),
                       ('vphot',    0.28   , True, 0    , 1),
                       ('vmax',     0.338  , True, 0, 1),
                       ('t0',       126000 , False),
                       ('tau',      1.69   , True, 0, 100),
                       ('vref',     0.     , False, 0, 1),
                       ('ve',       0.31   , True, 0, 1),
                       ('occult',   0.03   , True, 0, 2),
                       ('amp1',     0.28   , True, 0, 1),
                       ('amp2',     0.44   , True, 0, 1),
                       ('cen1',     15500e-10,  True, 14000e-10, 17000e-10),
                       ('cen2',     20200e-10,  True, 19000e-10, 22000e-10),
                       ('sig1',     580e-10,  True, 100e-10, 3000e-10),
                       ('sig2',     800e-10,  True, 100e-10, 3000e-10), 
                       ('lam0',     10500  ,  True , 9000   , 12000)
                       )
        if OB == "OB2_one_line":
            p.add_many(('T',        3950  , True, 2500 , 7500),
                       ('N',        2.7e-29 , True),
                       ('vphot',    0.248  , True, 0    , 1),
                       ('vmax',     0.28 , True, 0, 1),
                       ('t0',       212400, False),
                       ('tau',      1.5  , True, 0, 20),
                       ('vref',     0.     , False, 0, 1),
                       ('ve',       6.6    , True, 0, 10),
                       ('occult',   1.84   , True, 0.1, 10),
                       ('amp1',     0.62 , True, 0.01, 5),
                       ('amp2',     0.24 , True, 0.01, 5),
                       ('cen1',     15500e-10,  False, 14000e-10, 17000e-10),
                       ('cen2',     20200e-10,  False, 19000e-10, 22000e-10),
                       ('sig1',     580e-10,  False, 100e-10, 3000e-10),
                       ('sig2',     742e-10,  False, 100e-10, 3000e-10), 
                       ('lam0',     10500  ,  True , 9000   , 12000)
                       )
        #with open("./data/%s_w_gaussians.json"%OB, 'w') as outfile:
        #    p.dump(outfile)
        #with open("./data/%s_init_no_gaussian_low_v_2.json"%OB, 'w') as outfile:
        #    p.dump(outfile)
            
        with open("./data/%s_init.json"%OB, 'w') as outfile:
            print("./data/%s_init.json"%OB)
            p.dump(outfile)

if __name__ == '__main__':
    main()
# Out:
# ./data/OB1_one_line_init.json
# ./data/OB2_one_line_init.json
